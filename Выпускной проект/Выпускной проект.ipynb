# %% [markdown]
# <div class="alert alert-info">
# Привет, Кирилл! Меня зовут Светлана Чих и я буду проверять твой проект. Моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе. Предлагаю общаться на «ты». Но если это не удобно - дай знать, и мы перейдем на «вы».
#
# <div class="alert alert-success">
# <b>👍 Успех:</b> Зелёным цветом отмечены удачные и элегантные решения, на которые можно опираться в будущих проектах.
# </div>
# <div class="alert alert-warning">
# <b>🤔 Рекомендация:</b> Жёлтым цветом выделено то, что в следующий раз можно сделать по-другому. Ты можешь учесть эти комментарии при выполнении будущих заданий или доработать проект сейчас (однако это не обязательно).
# </div>
# <div class="alert alert-danger">
# <b>😔 Необходимо исправить:</b> Красным цветом выделены комментарии, без исправления которых, я не смогу принять проект :(
# </div>
# <div class="alert alert-info">
# <b>👂 Совет:</b> Какие-то дополнительные материалы
# </div>
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте по моим рекомендациям — пиши об этом.
# Мне будет легче отследить изменения, если ты выделишь свои комментарии:
# <div class="alert alert-info"> <b>🎓 Комментарий студента:</b> Например, вот так.</div>
# Пожалуйста, не перемещай, не изменяй и не удаляй мои комментарии. Всё это поможет выполнить повторную проверку твоего проекта быстрее.
#  </div>

# %% [markdown]
# # Банки — Анализ оттока клиентов
#
# <div style="border:solid Purple 2px; padding: 40px" >
#
# <u><b> Описание проекта:</b></u>
#
# Наш банк в срочном порядке ищет аналитиков уверенным владением «Python». Вашей главной задачей станет анализ оттока клиентов. Анализ покажет, какие клиенты уходят из банка, а так же поможет нам составить сегменты клиентов, которые склонны уходить из банка.
# «Метанпромбанк» — деньги не пахнут!
#
#
#
# <u><b> Цель:</b></u>
#
#   <li> Проанализировть клиентов регионального банка и выделить сегменты клиентов, которые склонны уходить из банка.</li>
#
# <u><b> Задачи:</b></u>
# <li>Провести исследовательский анализ данных, включающий исследование корреляций и приоритетов клиентов</li>
# <li>Проверить гипотезы(не менее двух гипотез)</li>
# <li>Сделать выводы о том, какие признаки стратегическом образом влияют на оттток и какие значения или интеравалы этих признаков связаны с отттоком</li>
# <li>Выделить не мелкие, но компактные высокоточные сегметны и приотизировать их </li>
# <li>Дать конкретные рекомендации по приоритентым сегментам</li>
# <li>Подготовить презентацию</li>
#
# <u><b> Описание датасета:</b></u>
#
# <li>USERID— идентификатор пользователя</li>
# <li>score — баллы кредитного скоринга</li>
# <li>city — город</li>
# <li>gender — пол</li>
# <li>age — возраст</li>
# <li>equity— количество баллов собственности</li>
# <li>balance-баланс на счете</li>
# <li>products - количество продуктов,которыми пользуется клиент</li>
# <li>credit_card — есть ли кредитная карта</li>
# <li>last_activity — активный клиент</li>
# <li>EST_SALARY — оценочный доход клиента</li>
# <li>сhurn — признак оттока</li>
#
# <u><b>План работы:</b></u>
#
# 1.Загрузка данных и подготовка к исследованию
# <li>Загрузка данных</li>
# <li>Обзор датасета (размер, содержание, сотответсвие типов данных)</li>
# <li>Промежуточный вывод</li>
#
# 2.Предобработка данных
# <li>Проверка на наличие пропусков и их анализ</li>
# <li>Проверка на наличие  дубликатов и их анализ</li>
# <li>Приведение наименований столбцов к единому стилю</li>
# <li>Проверка на наличие выбросов/аномалий и их анализ</li>
# <li>Промежуточный вывод</li>
#
# 3.Исследовательский анализ данных
# <li>Распределение признаков в разрезе оттока</li>
# <li>Составление портретов клиентов</li>
# <li>Корелляционный анализ</li>
# <li>Промежуточный вывод</li>
#
# 4.Проверка статистических гипотез
# <li>Проверка первой гипотезы</li>
# <li>Проверка второй гипотезы</li>
# <li>Промежуточный вывод</li>
#
# 5.Сегментация на основе статегических показателей
# <li>Промежуточный вывод</li>
#
# 6.Выводы и рекомендации
# <li>Итоговый вывод и рекомендации</li>
# <li>Презентация</li>

# %% [markdown]
# ## Загрузка данных и подготовка к исследованию

# %%
#Подгружаем необходимые библиотеки
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import plotly.graph_objs as go
from datetime import datetime, timedelta
import math as mth
from scipy import stats as st
sns.set(style="whitegrid")
colors =["#ef476f","#ffd166","#06d6a0","#118ab2","#073b4c"]
import re
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore") 
from statsmodels.stats.proportion import proportions_ztest
import itertools

# %%
#Загружаем датасет
df = pd.read_csv('/datasets/bank_scrooge.csv')

# %%
#Выводим первые строки
df.head()
# Out:
#    USERID  score       city gender   age  equity     balance  products  \
# 0  183012  850.0    Рыбинск      Ж  25.0       1    59214.82         2
# 1  146556  861.0    Рыбинск      Ж  37.0       5   850594.33         3
# 2  120722  892.0    Рыбинск      Ж  30.0       0         NaN         1
# 3  225363  866.0  Ярославль      Ж  51.0       5  1524746.26         2
# 4  157978  730.0  Ярославль      М  34.0       5      174.00         1
#
#    credit_card  last_activity  EST_SALARY  churn
# 0            0              1    75719.14      1
# 1            1              0    86621.77      0
# 2            1              1   107683.34      0
# 3            0              1   174423.53      1
# 4            1              0    67353.16      1

# %%
#Получаем информацию о датасете
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   USERID         10000 non-null  int64
#  1   score          10000 non-null  float64
#  2   city           10000 non-null  object
#  3   gender         10000 non-null  object
#  4   age            9974 non-null   float64
#  5   equity         10000 non-null  int64
#  6   balance        7705 non-null   float64
#  7   products       10000 non-null  int64
#  8   credit_card    10000 non-null  int64
#  9   last_activity  10000 non-null  int64
#  10  EST_SALARY     10000 non-null  float64
#  11  churn          10000 non-null  int64
# dtypes: float64(4), int64(6), object(2)
# memory usage: 937.6+ KB

# %% [markdown]
# <div style="background-color:aliceblue;padding:25px;"> Промежуточный вывод:
#     <li>Данные загружены</li>
#     <li>Выполнен обзор данных, по результатам которого выявлено:
#         <ul type="square">
#         <li> Датасет состоит из 12ти стоблцов и имеет 10 тыс строк </li>
#         <li> Название столбцов на этапе предобработки необходимо приводить к змеиному синтаксису</li>
#         <li> Столбцы score,age имеют тип float64 - на этапе предобработки изменю на int64</li>
#         <li> Значения столбца gender на этапе предобработки изменю на 1/0 (вместо М/Ж) и присвою тип данных int64</li>
#         <li> В столбцах age,balance имеются пропуски  - их анализ и дальнешие действия определю на этапе предобработки</li>
#         <ul type="square">

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Есть описание задачи, план реализации проекта, импортированы нужные библиотеки, датасет загружен и просмотрен
# </div>

# %% [markdown]
# ## Предобработка данных

# %%
#Приводим названия столбцов к змеиному синтаксису
df.columns = [x.lower() for x in df.columns]
df = (
    df.rename(columns={"userid": "user_id"})
)

# %%
#Изменяем типы данных в стоблцах score,age
df['score'] = df['score'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   user_id        10000 non-null  int64
#  1   score          10000 non-null  int64
#  2   city           10000 non-null  object
#  3   gender         10000 non-null  object
#  4   age            9974 non-null   float64
#  5   equity         10000 non-null  int64
#  6   balance        7705 non-null   float64
#  7   products       10000 non-null  int64
#  8   credit_card    10000 non-null  int64
#  9   last_activity  10000 non-null  int64
#  10  est_salary     10000 non-null  float64
#  11  churn          10000 non-null  int64
# dtypes: float64(3), int64(7), object(2)
# memory usage: 937.6+ KB

# %%
#df['age'] = df['age'].astype(int)

# %%
#Выведем строки с пропусками в стоблце age
df.query('age.isna()')
# Out:
#       user_id  score       city gender  age  equity     balance  products  \
# 1247   228075    932  Ярославль      М  NaN       5  7601719.20         2
# 2165   187635    692    Рыбинск      Ж  NaN       0         NaN         1
# 2444   221156    913  Ярославль      М  NaN       0         NaN         1
# 3091   138660    836     Ростов      Ж  NaN       5   294315.53         2
# 4912   210674    834    Рыбинск      М  NaN       1   238330.52         2
# 5470   218868    827    Рыбинск      Ж  NaN       4   448959.07         2
# 5495   151662    884    Рыбинск      Ж  NaN       0         NaN         1
# 7236   210135    908    Рыбинск      Ж  NaN       4  1120340.31         3
# 7248   219343    920    Рыбинск      Ж  NaN       0         NaN         1
# 7345   184913    829  Ярославль      Ж  NaN       3   188648.77         2
# 7409   214031    777  Ярославль      М  NaN       2   171510.23         1
# 8015   198635    670  Ярославль      Ж  NaN       0         NaN         1
# ...

# %%
#Распределение пропусков по значениям оттока (0/1)
df.query('age.isna()').groupby('churn')['churn'].count()
# Out:
# churn
# 0    25
# 1     1
# Name: churn, dtype: int64

# %% [markdown]
# Наличие пропусков не является признаком оттока клиентов.

# %%
#Определим долю пропусков в столбце age
print(f"доля пропусков в столбце age {df['age'].isna().sum()/df['age'].count():.1%}")
# Out:
# доля пропусков в столбце age 0.3%

# %% [markdown]
# Пропуски в столбце Age оставлю без изменений

# %%
#C учетом того, что доля пропущенных значений в столбце меньше одного процента,а удаление данных может оказать влияение при дальнешем анализе заполню пропуска медианным значением. Заполнение пропусков не окажет влияения на анализ пользователей где в процессе анализа будет задействован возраст в тоже время сохраним информацию о пользователях

# %%
#заполняем пропуски в age
#df['age'] = df['age'].fillna(df['age'].median())

# %% [markdown]
# <div class="alert alert-danger">
# <s><b>😔 Необходимо исправить:</b> Такая замена не может быть достоверной, эти пропуски можно или удалить, или оставить как есть</s>
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>🎓 Комментарий студента:</b> Замечание устранено</div>

# %%
print(f"доля пропусков в столбце balance {df['balance'].isna().sum()/df['balance'].count():.1%}")
# Out:
# доля пропусков в столбце balance 29.8%

# %%
#Распределение пропусков по филиалов
df.query('balance.isna()').groupby('city')['city'].count()
# Out:
# city
# Ростов        235
# Рыбинск       593
# Ярославль    1467
# Name: city, dtype: int64

# %%
#Распределение пропусков по значению оттока
df.query('balance.isna()').groupby('churn')['churn'].count()
# Out:
# churn
# 0    2282
# 1      13
# Name: churn, dtype: int64

# %% [markdown]
# Количество пропусков в столбце balance почти 30% заничительная доля в датасете, их исключение из дальнейшего анализа однозначно приведет к искожению результатов дальнейшей работы. В тоже время пропуски распределены по филиалам (нет явных закономерностей) и имеются у обоих категорий пользователей в разрезе оттока. На основании вышеизложенного предлагаю оставить данные пропуски без изменений. Изменения формата данных на int64 выполнить не представляется возможным в связи с наличием пропусков

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно! Эти пропуски лучше всего оставить "как есть"
# </div>

# %%
#Проверка явных дубликатов
df.duplicated().sum()
# Out:
# 0

# %%
# найдем дубликаты в столбце user_id:
df['user_id'].duplicated().sum()
# Out:
# 73

# %%
#Определим сущность дубликатов для примера возьмем один из выборки 
df.loc[df['user_id']==190253]
# Out:
#       user_id  score       city gender   age  equity    balance  products  \
# 231    190253    823    Рыбинск      М  37.0       4  373348.39         2
# 1583   190253    726  Ярославль      М  49.0       0        NaN         1
#
#       credit_card  last_activity  est_salary  churn
# 231             0              1   131947.92      1
# 1583            1              1   177700.78      0

# %%
# проверим распределение дубликатов по городам
df.query('user_id.duplicated()').groupby('city')['city'].count()
# Out:
# city
# Рыбинск      41
# Ярославль    32
# Name: city, dtype: int64

# %%
print(f"доля дубликатов по user_id {df['user_id'].duplicated().sum()/df['user_id'].count():.1%}")
# Out:
# доля дубликатов по user_id 0.7%

# %% [markdown]
# Наличие дубликатов может быть вызвано сбоем в системе (один id присваивается разным клиентам). Также выявлено, подобные дубликаты имеются только у клиентов из Ярославля и Рыбинска(системный сбой только по отделам в данных локациях). Доля дубликатов относительно генеральной совокупности меньше 1% согласно рекомендациям ментора оставлю данные дубликаты без изменений

# %%
#замена значений "М" на 1, "Ж" на 0:
df.loc[df['gender']=='М', 'gender'] = 1
df.loc[df['gender']=='Ж','gender'] = 0
#Изменяем типы данных в стоблце gender
df['gender'] = df['gender'].astype(int)

# %%
#Проверка аномалий выбросов
round(df.describe(),3)
# Out:
#           user_id      score   gender       age     equity       balance  \
# count   10000.000  10000.000  10000.0  9974.000  10000.000  7.705000e+03
# mean   171814.713    848.699      0.5    42.734      2.628  8.277943e+05
# std     33708.238     65.449      0.5    12.180      1.981  1.980614e+06
# min     94561.000    642.000      0.0    18.000      0.000  0.000000e+00
# 25%    142810.250    802.000      0.0    33.000      0.000  2.955542e+05
# 50%    172728.000    853.000      1.0    40.000      3.000  5.242722e+05
# 75%    201261.750    900.000      1.0    51.000      4.000  9.807058e+05
# max    229145.000   1000.000      1.0    86.000      9.000  1.191136e+08
#
#         products  credit_card  last_activity   est_salary      churn
# count  10000.000    10000.000      10000.000    10000.000  10000.000
# mean       1.870        0.680          0.524   147866.886      0.182
# std        0.793        0.466          0.499   139388.511      0.386
# ...

# %% [markdown]
# Мы видим, что в большинстве столбцов данные нормально распределены: среднее отличается от медианы незначительно, а стандартное отклонение невелико. Однако дополнительно проверим значения в столбцах est_salary и balance. В столбце est_salary имеются клиенты с доходом меньше МРОТ (на 2024 год МРОТ 19242 рубля). В стоблце balance имеются клиенты с нулевым балансом. Проверим вышеперечисленные аномалии

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно!
# </div>

# %%
# Посчитаем строки с клиентами, заработная плата которых ниже МРОТа:
df[df['est_salary']<19242]['user_id'].count()
# Out:
# 131

# %%
#Считаем долю
print(f"доля аномальных user_id по est_salary {df[df['est_salary']<19242]['user_id'].count()/df['user_id'].count():.1%}")
# Out:
# доля аномальных user_id по est_salary 1.3%

# %%
#Cчитаем количество клиентов с нулевым балансом
df[df['balance']==0]['user_id'].count()
# Out:
# 2

# %%
#Считаем долю
print(f"доля аномальных user_id по balance {df[df['balance']==0]['user_id'].count()/df['user_id'].count():.1%}")
# Out:
# доля аномальных user_id по balance 0.0%

# %% [markdown]
# С учетом коментариев ментора вышеперечисленные выбросы по столбцам est_salary и balance аномалиями не считаем

# %%
# создадим копии столбцов 'city' и 'gender'
df['city_2']=df['city']
df['gender_2']=df['gender']
df.head()
# Out:
#    user_id  score       city  gender   age  equity     balance  products  \
# 0   183012    850    Рыбинск       0  25.0       1    59214.82         2
# 1   146556    861    Рыбинск       0  37.0       5   850594.33         3
# 2   120722    892    Рыбинск       0  30.0       0         NaN         1
# 3   225363    866  Ярославль       0  51.0       5  1524746.26         2
# 4   157978    730  Ярославль       1  34.0       5      174.00         1
#
#    credit_card  last_activity  est_salary  churn     city_2  gender_2
# 0            0              1    75719.14      1    Рыбинск         0
# 1            1              0    86621.77      0    Рыбинск         0
# 2            1              1   107683.34      0    Рыбинск         0
# 3            0              1   174423.53      1  Ярославль         0
# 4            1              0    67353.16      1  Ярославль         1

# %%
# закодируем данные в столбцах city_2 и gender_2:

df = pd.get_dummies(df, columns = ['city_2', 'gender_2'])
df = df.rename (
    columns = ({
        'city_2_Ростов':'Ростов', 'city_2_Рыбинск':'Рыбинск','city_2_Ярославль':'Ярославль', 
        'gender_2_Ж':'female', 'gender_2_М':'male'}))
display(df.head())
# Out:
#    user_id  score       city  gender   age  equity     balance  products  \
# 0   183012    850    Рыбинск       0  25.0       1    59214.82         2
# 1   146556    861    Рыбинск       0  37.0       5   850594.33         3
# 2   120722    892    Рыбинск       0  30.0       0         NaN         1
# 3   225363    866  Ярославль       0  51.0       5  1524746.26         2
# 4   157978    730  Ярославль       1  34.0       5      174.00         1
#
#    credit_card  last_activity  est_salary  churn  Ростов  Рыбинск  Ярославль  \
# 0            0              1    75719.14      1       0        1          0
# 1            1              0    86621.77      0       0        1          0
# 2            1              1   107683.34      0       0        1          0
# 3            0              1   174423.53      1       0        0          1
# 4            1              0    67353.16      1       0        0          1
#
#    gender_2_0  gender_2_1
# 0           1           0
# ...

# %% [markdown]
# <div style="background-color:aliceblue;padding:25px;"> Промежуточный вывод:
#     <li>Выполнена проверка датасета на наличие пропусков и их анализ. Пропуски в столбце age заполнили медианным значением, пропуски в стобоце balance оставили без изменений</li>
#     <li>Выполнена проверка на наличие  дубликатов и их анализ. Дубликаты найдены в столбце user_id согласно рекомендациям ментора оставили их без изменений.Неявных дубликатов не обнаружено</li>
#     <li>Выполнено приведение наименований столбцов к единому стилю</li>
#     <li>Изменены типы данных в стоблцах score,age,gender(в столбце gender значения М/Ж заменили бинарными показателями 1/0)</li>
#     <li>Выполнена проверка на наличие выбросов/аномалий и их анализ.Аномальных значения с учетом рекомендаций ментора не обнаружено</li>
#     <li>Закодированы данные столбцов city и gender</li>
#     <li>Подготовлен промежуточный вывод</li>

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно!
# </div>

# %% [markdown]
# ## Исследовательский анализ данных

# %%
df['balance_na']=df['balance']
df['balance_na'] = df['balance_na'].apply(lambda x: 1 if pd.isna(x) else 0)

# %%
# рассмотрим центральные тенденции характеристик в разрезе оттока

df_churn = df.groupby('churn').agg({
                         'churn': 'count',
                         'equity': 'mean',
                         'products': 'mean', 
                         'credit_card': 'mean', 
                         'last_activity': 'mean', 
                         'score' : 'median', 
                         'age': 'median', 
                         'balance': 'median', 
                         'balance_na': 'mean', 
                         'est_salary': 'median'}).rename(columns = {'churn':'count'})
display(df_churn)
# Out:
#        count    equity  products  credit_card  last_activity  score   age  \
# churn
# 0       8180  2.374817  1.757579     0.709169       0.483741    848  40.0
# 1       1820  3.763736  2.375824     0.551099       0.702198    866  39.0
#
#           balance  balance_na  est_salary
# churn
# 0      475382.445    0.278973  118257.715
# 1      782410.470    0.007143  125390.620

# %%
# сравним центральные тенденции характеристик отточных и неотточных клиентов

pd.concat({
    'Не отточные': df_churn.iloc[0],
    'Отточные': df_churn.iloc[1],
    'Разница %': (df_churn.iloc[1]/df_churn.iloc[0]-1)*100},
    axis=1).sort_values('Разница %')
# Out:
#                  Не отточные       Отточные  Разница %
# balance_na          0.278973       0.007143 -97.439589
# count            8180.000000    1820.000000 -77.750611
# credit_card         0.709169       0.551099 -22.289450
# age                40.000000      39.000000  -2.500000
# score             848.000000     866.000000   2.122642
# est_salary     118257.715000  125390.620000   6.031661
# products            1.757579       2.375824  35.175918
# last_activity       0.483741       0.702198  45.159920
# equity              2.374817       3.763736  58.485343
# balance        475382.445000  782410.470000  64.585478

# %%
#Функция для котегоризации пользователей по уровню дохода
# def category_by_est_salary(df):
    
#     if df['est_salary'] <= 19242:
#         return 'крайне низкий'
    
#     elif df['est_salary'] <= 40000:
#         return 'низкий'
    
#     elif df['est_salary'] <= 100000:
#         return 'средний'
    
#     else:
#         return 'высокий'

# %% [markdown]
# <div class="alert alert-danger">
# <s><b>😔 Необходимо исправить:</b> Нельзя применять категоризацию (ни по каким признакам) до определения границ оттока, сейчас границы категорий могут не совпадать с границами оттока и сделают невозможным выделение отточных сегментов</s>
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>🎓 Комментарий студента:</b> Замечание устранено.Все строки с котегоризацией закоментированы</div>

# %%
# #Применем функцию
# df['salary_level'] = df.apply(category_by_est_salary, axis=1)

# %%
# df['salary_level'].value_counts()

# %%
# #строим столбчатую диаграмму
# df['salary_level'].value_counts().sort_values(ascending=False).plot(kind='bar')
# plt.xticks(rotation=45)
# plt.ylabel('кол-во клиентов')
# plt.xlabel('уровень дохода')
# plt.title('Распределение клиентов по уровню дохода');

# %% [markdown]
# <!-- Проведем котигоризацию клиентов по возрасту с учетом следующих интервалов:
# <li>1.18-24 </li>
# <li>2.25-44 </li>
# <li>3.45-64</li>
# <li>4.65 и более</li> -->

# %%
# def category_by_age(df):
    
#     if 18 <= df['age'] <= 24:
#         return '18-24'
    
#     elif 25 <= df['age'] <= 44:
#         return '25-44'
    
#     elif 45 <= df['age'] <= 64:
#         return '45-64'
    
#     else:
#         return '65 и старше'

# %%
# df['age_category'] = df.apply(category_by_age, axis=1)

# %%
# df['age_category'].value_counts()

# %%
# df['age_category'].value_counts().sort_values(ascending=False).plot(kind='bar')
# plt.xticks(rotation=45)
# plt.ylabel('кол-во клиентов')
# plt.xlabel('возрастная категория')
# plt.title('Распределение клиентов по возрасту');

# %% [markdown]
# <!-- Добавим категоризация клиентов по уровню кредитного скоринга.
#
# <li>Ресурс банки.ру предлагает следующую шкалу кредитного рейтинга :
#
# <li>0-595 - вероятность получения кредита отсутствует, крайне низкий уровень</li>
#
# <li>596-765 - вероятность получения кредита мала, низкий уровень</li>
#
# <li>766-895 - вероятность получения кредита имеется, средний уровень</li>
# <li>896-950 - вероятность получения кредита значительная, уровень выше среднего</li>
# <li>951 и более - вероятность получения кредита 100%, высокий уровень</li> -->

# %%
# def category_by_score(df):
    
#     if df['score'] < 595:
#         return 'крайне низкий'
    
#     elif 596 <= df['score'] < 765:
#         return 'низкий'
    
#     elif 766 <= df['score'] < 895:
#         return 'средний'
#     elif 896 <= df['score'] < 950:
#         return 'выше среднего'
#     else:
#         return 'высокий'


# df['score_level'] = df.apply(category_by_score, axis=1)

# %%
# df['score_level'].value_counts()

# %%
# df['score_level'].value_counts().sort_values(ascending=False).plot(kind='bar')
# plt.xticks(rotation=45)
# plt.ylabel('кол-во клиентов')
# plt.xlabel('уровень кредитного скоринга')
# plt.title('Распределение клиентов по уровню кредитного скоринга');

# %% [markdown]
# <!-- Также добавим категоризацию клиентов банка по уровню баланса на счете.
# Установим следующие раницы групп клиентов в разрезе уровня баланса на счете:
#
# <li>До 100000 - крайне низкий уровень баланса</li>
#
# <li>100000-300000 - низкий уровень баланса</li>
#
# <li>300000-1000000 - средний уровень баланса</li>
#
# <li>1000000 и выше - высокий уроень баланса</li> -->

# %%
# def category_by_balance(df):
    
#     if df['balance'] < 50000:
#         return 'крайне низкий'
    
#     elif 50000 <= df['balance'] < 300000:
#         return 'низкий'
    
#     elif 300000 <= df['balance'] < 530000:
#         return 'средний'
    
#     elif df['balance'] >= 530000:
#         return 'высокий'

# df['balance_level'] = df.apply(category_by_balance, axis=1)

# %%
# df['balance_level'].value_counts()

# %%
# df['balance_level'].value_counts().sort_values(ascending=False).plot(kind='bar')
# plt.xticks(rotation=45)
# plt.ylabel('кол-во клиентов')
# plt.xlabel('уровень баланса')
# plt.title('Распределение клиентов по уровню баланса на счете');

# %%
#посмотрим на распределение признаков с дискретными значениями
for column in df[['city', 'gender','equity', 'products', 'credit_card', 'last_activity']].columns:
    ax = sns.countplot(x = column, data = df)
    plt.title('Распределение клиентов по ' + column)
    plt.ylabel('Количество клиентов')
    plt.show();

# %% [markdown]
# <li>Наибольшее количество клиентов в Рыбинске</li>
# <li>По гендерному признаку существенных различий в долях не имеется</li>
# <li>У большинства клиентов 0 баллов собственности</li>
# <li>У наибольшего количества клиентво в наличии 2 продукта банка</li>
# <li>Доля клиентов имеющих кредитную карту больше неимеющих </li>
# <li>Доля активных клиентов незначительно больше чем неактивных</li>

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно!
# </div>

# %%
#посмотрим на распределение признаков с непрерывнми значениями (возраст отнесем в эту категорию)
for column in df[['score', 'age', 'est_salary', 'balance']].columns:
    sns.distplot(df[column], bins=100)
    plt.xticks(rotation=45)
    plt.title('Распределение клиентов по ' + column)
    plt.ylabel('Плотность распределения')
    plt.xlabel('Значение')
    plt.show();

# %% [markdown]
# <li>Наибольшее количество клиентов имеют рейтинг в диапозоне от 800 до 910 </li>
# <li>Наибольшее число клиентов возрастом 30 - 45 лет</li>
# <li>У наибольшего количества клиентов доход составляет 100000-200000 тыс</li>
# <li>В основном у клиентов баланс на счете близок к нулевому</li>

# %% [markdown]
# <div class="alert alert-danger">
#     <s><b>😔 Необходимо исправить:</b> Здесь должны быть какие то выводы</s>
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>🎓 Комментарий студента:</b> Замечание устранено.Выводы под графиками добавлены

# %%
# #посмотрим на диаграммы размахов признаков с непрерывными значениями (в т.ч. возраст)
# for column in df[['score', 'age', 'est_salary', 'balance']]:
#     ax = sns.boxplot(x=df[column])
#     plt.xticks(rotation=45)
#     plt.title('Распределение ' + column)
#     plt.show();

# %% [markdown]
# <div class="alert alert-danger">
#     <s><b>😔 Необходимо исправить:</b> И здесь очень не хватает выводов</s>
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>🎓 Комментарий студента:</b> Замечание устранено.Выводы под графиками выше

# %%
#df['score'].value_counts().head()

# %%
# #построим матрицу корреляции для признаков клиентов банка
# plt.figure(figsize=(12, 12))
# sns.heatmap(df.corr() , annot = True, fmt = '0.2f', linewidths=1)
# plt.show();

# %% [markdown]
# <div class="alert alert-danger">
# <s><b>😔 Необходимо исправить:</b> user_id не является признаком и не должен попадать в расчет корреляции, для категориальных признаков не может быть применена корреляция Пирсона, нажно использовать другие методы, например, Phik</s>
#
# https://towardsdatascience.com/phik-k-get-familiar-with-the-latest-correlation-coefficient-9ba0032b37e7
#
# </div>

# %%
df.groupby('churn').mean().T
# Out:
# churn                      0             1
# user_id        172004.359046  1.709623e+05
# score             845.428362  8.634011e+02
# gender              0.467237  6.500000e-01
# age                43.020846  4.145025e+01
# equity              2.374817  3.763736e+00
# balance        733982.585648  1.133993e+06
# products            1.757579  2.375824e+00
# credit_card         0.709169  5.510989e-01
# last_activity       0.483741  7.021978e-01
# est_salary     147783.200108  1.482430e+05
# Ростов              0.140709  1.461538e-01
# Рыбинск             0.276039  2.401099e-01
# Ярославль           0.583252  6.137363e-01
# gender_2_0          0.532763  3.500000e-01
# gender_2_1          0.467237  6.500000e-01
# balance_na          0.278973  7.142857e-03

# %%
#посмотрим на распределение признаков с дискретными значениями
for column in df[['city', 'gender','equity', 'products', 'credit_card', 'last_activity']].columns:
    ax = sns.countplot(x = column, hue = 'churn', data = df)
    plt.title('Количества лояльных и ушедших клиентов в зависимости от ' + column)
    plt.legend(['Лояльные', 'Ушедшие'])
    plt.show();

# %%
# визуализируем взаимосвязь 'churn' - 'score'

plt.figure(figsize=(10,3))
plt.legend(['Не отточные', 'Отточные'])
sns.kdeplot(df[df['churn'] == 0]['score'], clip=(0.0, 2000000.0), common_norm=False, color='green')
sns.kdeplot(df[df['churn'] == 1]['score'], clip=(0.0, 2000000.0), common_norm=False, color='red')
plt.legend(['Не отточные', 'Отточные'])
plt.show()

# %%
# визуализируем взаимосвязь 'churn' - 'balance'

plt.figure(figsize=(10,3))
sns.kdeplot(df[df['churn'] == 0]['balance'], clip=(0.0, 2000000.0), common_norm=False, color='green')
sns.kdeplot(df[df['churn'] == 1]['balance'], clip=(0.0, 2000000.0), common_norm=False, color='red')
plt.legend(['Не отточные', 'Отточные'])
plt.show()

# %%
# визуализируем взаимосвязь 'churn' - 'est_salary'

plt.figure(figsize=(10,3))
sns.kdeplot(df[df['churn'] == 0]['est_salary'], clip=(0.0, 300000.0), common_norm=False, color='green')
sns.kdeplot(df[df['churn'] == 1]['est_salary'], clip=(0.0, 300000.0), common_norm=False, color='red')
plt.legend(['Не отточные', 'Отточные'])
plt.show()

# %%
plt.figure(figsize=(9,3))
plt.legend(['Не отточные', 'Отточные'])
sns.histplot(df[df['churn'] == 0]['age'], discrete=True, stat='density', common_norm=False, color='Green');
sns.histplot(df[df['churn'] == 1]['age'], discrete=True, stat='density', common_norm=False, color='Red');
plt.legend(['Не отточные', 'Отточные'])
plt.show()

# %%
#посмотрим на распределение признаков с непрерывнми значениями (возраст отнесем в эту категорию)
for column in df[['score', 'age', 'est_salary', 'balance']].columns:
    sns.distplot(df.query('churn == 0')[column], bins = 100)
    sns.distplot(df.query('churn == 1')[column], bins = 100)
    plt.title('Распределение лояльных и ушедших клиентов по ' + column)
    plt.ylabel('Плотность распределения')
    plt.xlabel('Значение')
    plt.legend(['Лояльные', 'Ушедшие'])
    plt.show();

# %% [markdown]
# <div class="alert alert-danger">
# <s><b>😔 Необходимо исправить:</b> Здесь нужно сразу отметить границы оттока по каждому признаку (и провести такое исследование для всех признаков)</s>
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>🎓 Комментарий студента:</b> Замечание устранено.

# %% [markdown]
#  <div class="alert alert-success">
#  <b>👍 Успех:</b> Все верно!
#  </div>

# %%
churn_mean=df['churn'].mean()
fig, axes = plt.subplots(3,3, figsize=(15, 12))
n=0
for categorical in ['city', 'equity', 'products']:
    # выводим количество отточных клиентов в категории
    sns.countplot(data=df[df['churn'] == 1], x=categorical, palette="coolwarm", ax=axes[n][1])
    axes[n][1].set_ylabel("Количество отточных")

    # выводим количество всех клиентов в категории
    sns.countplot(data=df, x=categorical, palette="coolwarm", ax=axes[n][2])
    axes[n][2].set_ylabel("Общее количество")

    # выводим уровень отточности клиентов в категории
    levels=df.groupby(categorical).agg({'churn': 'mean'}).reset_index()
    sns.barplot(data=levels, x=categorical, y='churn', ax=axes[n][0])
    axes[n][0].axhline(y=churn_mean, color='red', alpha=0.2)
    axes[n][0].set_ylabel("Уровень отточных (%)")
    # выводим метки на barplot
    #axes[n][0].bar_label(axes[n][0].containers[0], fmt='%.2f%%', label_type='center')
    labels=levels['churn'].values.round(2)
    rects=axes[n][0].containers[0].patches
    for rect, label in zip(rects, labels):
        axes[n][0].text(rect.get_x() + rect.get_width()/2, rect.get_height(), label, ha="center", va="bottom")

    n+=1
fig.suptitle("Уровень и число отточных клиентов в разрезе категориальных характеристик");
plt.show()

# %%
figure, axis = plt.subplots(1,3, figsize=(10, 3))
figure.suptitle("Уровень отточных клиентов в разных городах");

df.groupby('churn').agg({'Ростов': 'sum'}).plot(ax=axis[0],kind='pie',y='Ростов',autopct='%0.1f%%',legend=False,labeldistance=None);
df.groupby('churn').agg({'Рыбинск': 'sum'}).plot(ax=axis[1],kind='pie',y='Рыбинск',autopct='%0.1f%%',legend=False,labeldistance=None);
df.groupby('churn').agg({'Ярославль': 'sum'}).plot(ax=axis[2],kind='pie',y='Ярославль',autopct='%0.1f%%',legend=False,labeldistance=None);
axis[2].legend(['Неотточных','Отточных'], bbox_to_anchor=(1, 1.02), loc='upper left')
plt.show()

# %%
figure, axis = plt.subplots(1,2, figsize=(10, 3))
figure.suptitle("Уровень отточных клиентов среди мужчин и женщин");

df.groupby('churn').agg({'gender_2_1': 'sum'}).plot(ax=axis[0],kind='pie',y='gender_2_1',autopct='%0.1f%%',legend=False,labeldistance=None);
df.groupby('churn').agg({'gender_2_0': 'sum'}).plot(ax=axis[1],kind='pie',y='gender_2_0',autopct='%0.1f%%',legend=False,labeldistance=None);
axis[1].legend(['Неотточных','Отточных'], bbox_to_anchor=(1, 1.02), loc='upper left')
axis[0].set(ylabel='Мужчины')
axis[1].set(ylabel='Женщины')
plt.show()

# %%
figure, axis = plt.subplots(1,2, figsize=(10, 3))
figure.suptitle("Уровень отточных клиентов в разрезе использования кредитки");

churn_level=df.groupby(['credit_card']).agg({'churn':'mean'})['churn']
axis[1].pie(x=[1 - churn_level.loc[0],churn_level.loc[0]],autopct='%.0f%%')
axis[0].pie(x=[1 - churn_level.loc[1],churn_level.loc[1]],autopct='%.0f%%')
axis[1].legend(['Неотточных','Отточных'], bbox_to_anchor=(1, 1.02), loc='upper left')
axis[0].set(ylabel='С кредиткой')
axis[1].set(ylabel='Без кредитки')
plt.show()

# %%
figure, axis = plt.subplots(1,2, figsize=(10, 3))
figure.suptitle("Уровень отточных клиентов по в разрезе активности");

churn_level=df.groupby(['last_activity']).agg({'churn':'mean'})['churn']
axis[1].pie(x=[1 - churn_level.loc[0],churn_level.loc[0]],autopct='%.0f%%')
axis[0].pie(x=[1 - churn_level.loc[1],churn_level.loc[1]],autopct='%.0f%%')
axis[1].legend(['Неотточных','Отточных'], bbox_to_anchor=(1, 1.02), loc='upper left')
axis[0].set(ylabel='Активные')
axis[1].set(ylabel='Не активные')
plt.show()

# %% [markdown]
# Вывод: Выделим, на основе получившихся графиков, признаки оказывающие наибольшее влияние на отток клиентов:

# %% [markdown]
# <div style="background-color:aliceblue;padding:25px;"> Промежуточный вывод:
# Выделим, на основе получившихся графиков, признаки оказывающие наибольшее влияние на отток клиентов:
#
# <li>баллы кредитного рейтинга score от 820 до 910</li>
# <li>баланс balance от 950K</li>
# <li>оценочный доход клиента est_salary от 100K до 230K</li>
# <li>возраст age о 25 до 35 либо от 50 до 60</li>
# <li>баллов собственности equity больше или равно 3</li>
# <li>продуктов products больше или равно 3</li>
# <li>пол gender мужчина</li>
# <li>кредитной карты credit_card нет</li>
# <li>активен last_activity да</li>
# <li>Разница уровня оттока по городам очень мала, проверим её ниже с помощью метода гипотиз.</li>

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно!
# </div>

# %% [markdown]
# ## Проверка статистических гипотез

# %% [markdown]
# Гипотеза №1: о различии дохода между клиентами, которые ушли и которые остались
#
# H_0: доходы оставшихся и отточных клиентов равны;
# H_1: доходы оставшихся и отточных клиентов не равны.
#
# Для проверки гипотезы проведем t-test и u-test
# alpha = 0.05 # критический уровень статистической значимости
#
# Чтобы понять, можно ли применять t-тест, нужно проверить три условия:
#
# Генеральные совокупности не зависят друг от друга.
# Выборочные средние нормально распределены.
# Дисперсии рассматриваемых генеральных совокупностей равны.
# Проверим наши генеральные совокупности на соответствие критериям для проведения t-testa

# %%
a = df[df['churn'] == 1]['est_salary']
b = df[df['churn'] == 0]['est_salary']

# %%
sns.histplot(df[df['churn'] == 0]['est_salary'])
sns.histplot(df[df['churn'] == 1]['est_salary'])
# Out:
# <AxesSubplot:xlabel='est_salary', ylabel='Count'>

# %%
# проведём тест на соотвествие данных о доходах отточных клиентов нормальному распределеню

alpha = 0.05  # критический уровень статистической значимости

shapiro_test_stat, p_value = st.shapiro(a)

print('p-значение: ', p_value)
if p_value < alpha:
    print('Распределение не нормально')
else:
    print('Нормальное распределение')
# Out:
# p-значение:  0.0
# Распределение не нормально

# %%
# проведём тест на соотвествие данных о доходах неотточных клиентов нормальному распределеню

alpha = 0.05  # критический уровень статистической значимости

shapiro_test_stat, p_value = st.shapiro(b)

print('p-значение: ', p_value)
if p_value < alpha:
    print('Распределение не нормально')
else:
    print('Нормальное распределение')
# Out:
# p-значение:  0.0
# Распределение не нормально

# %%
# оценим дисперсии

print(df[df['churn'] == 0]['est_salary'].var())
print(df[df['churn'] == 1]['est_salary'].var())
# Out:
# 20392519451.455894
# 15107976364.850912

# %% [markdown]
# Вывод:
#
# Генеральные совокупности не зависят друг от друга;
# Распределение значений не является нормальным;
# Дисперсии не равны.
# При отсутствии нормального распределения сравниваемых выборок вместо t-критерия Стьюдента используются аналогичные методы непараметрической статистики, среди которых наиболее известными является U-критерий Манна — Уитни.
# Таким образом, выборки не подходят для проведения t-testa

# %%
# проведем t-test

alpha = 0.05

results = st.ttest_ind(a, b)

print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-значение: 0.8987254468291451
# Не получилось отвергнуть нулевую гипотезу

# %%
# проведем u-test

alpha = 0.05  

results = st.mannwhitneyu(a, b)

print('p-значение: ', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print(
        'Не получилось отвергнуть нулевую гипотезу'
    )
# Out:
# p-значение:  0.000243559272811695
# Отвергаем нулевую гипотезу

# %% [markdown]
# Вывод: В данном случае, распределение не является нормальным, поэтому был выбран непараметрический тест U-критерий Манна — Уитни.
#
# Таким образом, отвергаем нулевую гипотезу, доходы оставшихся и отточных клиентов не равны

# %% [markdown]
# Гипотеза №2: о влиянии георгафии на отток
#
# H_0: отток зависит от города клиента;
# H_1: отток не зависит от города клиента.
#
# Для проверки гипотезы проведем t-test и u-test
# alpha = 0.05
#
# Чтобы понять, можно ли применять t-тест, нужно проверить три условия:
#
# Генеральные совокупности не зависят друг от друга.
# Выборочные средние нормально распределены.
# Дисперсии рассматриваемых генеральных совокупностей равны.
# Проверим наши генеральные совокупности на соответствие критериям для проведения t-testa

# %%
# выведем набор значений в выборках
print(df[df['city'] == 'Ростов']['churn'].unique())
print(df[df['city'] == 'Рыбинск']['churn'].unique())
print(df[df['city'] == 'Ярославль']['churn'].unique())
# Out:
# [0 1]
# [1 0]
# [1 0]

# %% [markdown]
# Выборки являются набором бинарных значений, поэтому t-test который предназначен для нормально распределённых данных, применять нельзя. Сравнение средних не даст корректного результата.
#
# Проведём c помощью библиотеки statsmodels z-test для проверки гипотезы.

# %%
# проведем z-test для категории города

# критический уровень статистической значимости
alpha = 0.05

# уровень оттока генеральной совокупности
churn_val = df['churn'].mean()

for city in ['Ростов', 'Рыбинск', 'Ярославль']:

    # количество испытаний
    nobs = df[df['city']==city]['churn'].count()

    # количество успешных
    successes = df[(df['city']==city) & (df['churn']==1)]['churn'].count()

    # z-test
    z_stat, pval = proportions_ztest(successes, nobs, churn_val)

    print('p-значение:', '{0:0.3f}'.format(pval))

    if pval < alpha:
        print('Отвергаем нулевую гипотезу для города', city)
    else:
        print('Не получилось отвергнуть нулевую гипотез удля города', city)
# Out:
# p-значение: 0.581
# Не получилось отвергнуть нулевую гипотез удля города Ростов
# p-значение: 0.005
# Отвергаем нулевую гипотезу для города Рыбинск
# p-значение: 0.131
# Не получилось отвергнуть нулевую гипотез удля города Ярославль

# %%
# проведем u-test для категории города

# критический уровень статистической значимости
alpha = 0.05

for city in ['Ростов', 'Рыбинск', 'Ярославль']:
    utest_stat, pval = st.mannwhitneyu(df['churn'], df[df['city']==city]['churn'])
    print('p-значение: ', pval)
    if results.pvalue < alpha:
        print('Отвергаем нулевую гипотезу для города', city)
    else:
        print('Не получилось отвергнуть нулевую гипотезу для города', city)
# Out:
# p-значение:  0.6020203980124814
# Отвергаем нулевую гипотезу для города Ростов
# p-значение:  0.016767897530501296
# Отвергаем нулевую гипотезу для города Рыбинск
# p-значение:  0.22676024447809306
# Отвергаем нулевую гипотезу для города Ярославль

# %% [markdown]
# <div style="background-color:aliceblue;padding:25px;"> Промежуточный вывод:
# <li>Доходы отточных и неотточных клиентов не равны;</li>
# <li>Отток не зависит от города клиента.</li>

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Гипотезы сформулированы и проверены!
# </div>

# %% [markdown]
# ## Сегментация на основе статегических показателей

# %% [markdown]
# Построим карту корреляции чтобы проанализировать зависимости между категориями и возможно или совсем отбросить излишние характеристики при сильной корреляци, или учесть что ин стоит разнести по разным сегментам в случает наличия умеренной корреляции.

# %%
correlation = df[['churn',
                  'age',
                  'credit_card',
                  'last_activity',
                  'equity',
                  'products',
                  'balance_na',
                  'balance',
                  'est_salary',
                  'score'
                 ]].corr()
plt.figure(figsize=(15,15))
sns.heatmap(correlation, center=0, annot=True, fmt=".1f", cmap='coolwarm')
plt.title('Корреляция между разными характеристиками')
plt.show()

# %% [markdown]
#
# По шкале Чеддока, корреляцию оттока с характеристиками можно оценить как:
# слабая - age, male, credit_card, last_activity, balance_na, balance, est_salary, score. умеренная - equity, products.
#
# Можно заметить умеренную корреляцию между balance, est_salary и score. Поэтому лучше стараться выносить эти признаки в разные сегменты, чтобы максимизировать покрытие.
#
# Довольно сложно вручную сразу уметь подбирать сегменты. Поэтому воспользуемся методом перебора комбинаций сегментов. Но из списка результатов автоматического перебора будем выбирать не первый попавшийся (топовый) набор, а выберём такой чтобы учесть те замечания которые делали в предыдущих разделах.

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно!
# </div>

# %%
# средняя отточность по датасету
gauge_churn = df['churn'].mean()
print('Средняя отточность по банку:',"{:.2%}".format(gauge_churn),'\n')

# формализованный набор условий на основе признаков отточности 
c=[ '',
    'equity >= 3' ,
    'last_activity == 1',
    'gender_2_1 == 1',
    '100000 <= est_salary <= 230000',
    'credit_card == 0',
    '25 <= age <= 35',
    '50 < age <= 60',
    '820 <= score <= 910',
    'balance > 950000'
]

gauge_churn = df['churn'].mean()

# вычисление отточности сегмента и проверка размера
def query_churn_mean(q):
    if q == '':
        return 0
    cm = df.query(q).agg({"churn":['mean','count']}).values
    if cm[1] < 500:
        #print('too small')
        return 0
    if cm[1] > 5000:
        #print('too big')
        return 0
    else:
        return round(cm[0][0],2)

# соединяем признаки в сегмент
def query_concat(a,op):
    q=''
    for i in a:
        if i != '':
            q = i if q == '' else q + op + i
    return q

# соединяем сегменты в одну выборку
def query_concat_or(a):
    q=''
    for i in a:
        if i != '':
            q = '(' + i if q == '' else q + ') or (' + i
    return q + ')'


best_k=0
best_q=''
i=0

for x in list(itertools.permutations([0,1,2,3], 3)):
    for y in list(itertools.permutations([0,4,5,6], 3)):
        for z in list(itertools.permutations([0,7,8,9], 3)):
            i+=1
         
            if i > 1000:
                break
            #print(x[0],y[0],z[0],' | ',x[1],y[1],z[1],' | ',x[2],y[2],z[2])
            segment_1=query_concat([c[x[0]],c[y[0]],c[z[0]]],' and ')
            segment_2=query_concat([c[x[1]],c[y[1]],c[z[1]]],' and ')
            segment_3=query_concat([c[x[2]],c[y[2]],c[z[2]]],' and ')
            #print(q1,'|',q2,'|',q3)
            q1_k=query_churn_mean(segment_1)
            q2_k=query_churn_mean(segment_2)
            q3_k=query_churn_mean(segment_3)
            # проверяем условие по отточности сегментов
            if q1_k > 2*gauge_churn and q2_k > 2*gauge_churn and q3_k > 2*gauge_churn:
                q = query_concat_or([segment_1,segment_2,segment_3])
                t_k=query_churn_mean(q)
                if t_k > best_k:
                    best_q = q
                    best_k = t_k
                    print('+ Найден более отточный набор Churn mean:',best_k,'(',q1_k,q2_k,q3_k,');',
                          'Churn count: ',df.query(best_q)['churn'].sum())
                    print('Сегменты:\n', best_q.replace(" or ", "\n "),'\n')

print('Завершение за итераций:',i)
# Out:
# Средняя отточность по банку: 18.20%
#
# + Найден более отточный набор Churn mean: 0.38 ( 0.42 0.37 0.46 ); Churn count:  970
# Сегменты:
#  (100000 <= est_salary <= 230000 and balance > 950000)
#  (equity >= 3 and 50 < age <= 60)
#  (last_activity == 1 and credit_card == 0 and 820 <= score <= 910)
#
# + Найден более отточный набор Churn mean: 0.39 ( 0.42 0.37 0.45 ); Churn count:  1015
# Сегменты:
#  (100000 <= est_salary <= 230000 and balance > 950000)
#  (equity >= 3 and 50 < age <= 60)
#  (last_activity == 1 and 25 <= age <= 35 and 820 <= score <= 910)
#
# + Найден более отточный набор Churn mean: 0.4 ( 0.37 0.44 0.45 ); Churn count:  916
# Сегменты:
#  (credit_card == 0 and 50 < age <= 60)
#  (equity >= 3 and 100000 <= est_salary <= 230000 and balance > 950000)
#  (last_activity == 1 and 25 <= age <= 35 and 820 <= score <= 910)
#
# Завершение за итераций: 1535

# %% [markdown]
# Как и предпологали, выберем два возрастных сегмента и один по уровню обеспеченности:

# %% [markdown]
# Сегмент 1

# %%
display(df.query('credit_card == 0 and 50 < age <= 60').agg({'churn':['mean','count']}))
# Out:
#             churn
# mean     0.366044
# count  642.000000

# %% [markdown]
# Возраст 50-60 лет
# Наличие кредитной карты: нет
# Количество клиентов: 642
# Уровень отточности: 37%

# %% [markdown]
# Сегмент 2

# %%
display(df.query('equity >= 3 and 100000 <= est_salary <= 230000 and balance > 950000').agg({'churn':['mean','count']}))
# Out:
#              churn
# mean      0.435824
# count  1044.000000

# %% [markdown]
# Баллы собственности более 3
# Доход 100,000-230,000
# Баланс более 950,000
# Количество клиентов: 1044
# Уровень отточности: 44%

# %% [markdown]
# Сегмент 3

# %%
display(df.query('last_activity == 1 and 25 <= age <= 35 and 820 <= score <= 910').agg({'churn':['mean','count']}))
# Out:
#             churn
# mean     0.452899
# count  828.000000

# %% [markdown]
# Возраст 25-35 лет
# Кредитный рейтинг 830-910
# Активность: да
# Количество клиентов: 828
# Уровень отточности: 45%

# %% [markdown]
# <div style="background-color:aliceblue;padding:25px;"> Промежуточный вывод:
# <li>Выполнена сегментация на основе статегических показателей</li>
# <li>Подготовлен промежуточный вывод.</li>

# %% [markdown]
#  <div class="alert alert-success">
#  <b>👍 Успех:</b> Все верно!
#  </div>

# %% [markdown]
# ## Выводы и рекомендации

# %% [markdown]
# Сегмент №1
# <li>Возраст 50-60 лет</li>
# <li>Наличие кредитной карты: нет</li>
# <li>Количество клиентов: 642</li>
# <li>Уровень отточности: 37%</li>
# Рекомендации:
# <li>Предложить кредитную карту</li>
#
# Сегмент №2
# <li>Баллы собственности более 3</li>
# <li>Доход 100,000-230,000</li>
# <li>Баланс более 950,000</li>
# <li>Количество клиентов: 1044</li>
# <li>Уровень отточности: 44%</li>
# Рекомендации:
# <li>Предложить уникальные условия по накопительным счетам</li>
# <li>Предложить продукты страхования собственности</li>
#
# Сегмент №3
# <li>Возраст 25-35 лет</li>
# <li>Кредитный рейтинг 830-910</li>
# <li>Активность: да</li>
# <li>Количество клиентов: 828</li>
# <li>Уровень отточности: 45%</li>
# Рекомендации:
# <li>Предложить кредит</li>
#
# Ссылка на презентацию:https://disk.yandex.ru/i/3GvCTW5XPhNsEA

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Уважаемый проверяющий прошу на данном этапе выполнить проверку моей работы и указать на ошибки, мне на этапе подготовки данных не учтены аномалии и выбросы что искажает данные</div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>🤔 Рекомендация:</b> 1) не нужно выделять никакие категории 2) нужно для каждого признака найти отточные значения 3) с помощью quere и отточных значений выделить несколько сегментов и описать их, дать рекомендации по удержанию
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <s><b>😔 Необходимо исправить V2:</b> Большая часть ячеек не выполняется, нужно исправить всю работу, у тебя изменилось количество и название колонок, и это не учтено в работе</s>
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>V2 Комментарий студента:</b> Замечание устранено, все ячейки выполняются. Работы по изменению колонок перенесены на этап предобработки данных - выполнение указанных работ добавлены в промежуточный вывод соответсвующего раздела</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Хорошая работа, молодец! Все данные исследованы, много визуализации, сделаны выводы по всем разделам, достаточное количество рассуждений и комментариев, в презентации соблюден баланс текстовой и графической информации
# </div>
